# %% [markdown]
# This notebook contains the code used in the BigComp 2022 paper: <br>
# <b>Heeryon Cho, Woo-Kyu Kang, Younsoo Park, Sungeu Chae, and Seong-joon Kim, "Multi-label Facial Emotion Recognition Using Korean Drama Movie Clips," BigComp 2022.</b>
# ### Autoencoder /  Classify 6 Basic Emotions

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Input
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random as rn
import os
import collections

# %%
import warnings
import logging
logging.getLogger('tensorflow').disabled = True
warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# Record cell run time.
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.7/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# time: 428 µs (started: 2022-11-20 15:37:56 +00:00)

# %%
# Set seed for reproducibility.

set_seed = 46
np.random.seed(set_seed)
rn.seed(set_seed)
tf.random.set_seed(set_seed)
# Out:
# time: 1.22 ms (started: 2022-11-20 15:37:56 +00:00)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# time: 3.03 s (started: 2022-11-20 15:37:56 +00:00)

# %% [markdown]
# ### Load pretrained autoencoder.

# %%
# Create autoencoder model (skeleton) for loading pretrained weights.

def create_autoencoder():
    # Define the model
    model = Sequential()

    #1st convolution layer
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=(64,64,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

    #2nd convolution layer
    model.add(Conv2D(32,(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

    #3rd convolution layer
    model.add(Conv2D(32,(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))    

    #1st deconvolution layer
    model.add(Conv2DTranspose(32,(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(UpSampling2D((2, 2)))
    
    #2nd deconvolution layer
    model.add(Conv2DTranspose(32,(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(UpSampling2D((2, 2)))

    #3rd deconvolution layer
    model.add(Conv2DTranspose(32,(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(UpSampling2D((2, 2)))    

    model.add(Conv2D(3,(3, 3), padding='same'))
    model.add(Activation('sigmoid'))
    
    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy')
    model.summary()
    
    return model
# Out:
# time: 3.52 ms (started: 2022-11-20 15:37:59 +00:00)

# %%
# Load pretrained autoencoder weights.

checkpoint_path = "/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/model/autoencoder.ckpt"
autoencoder = create_autoencoder()
autoencoder.load_weights(checkpoint_path)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  activation (Activation)     (None, 64, 64, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        9248
#
#  activation_2 (Activation)   (None, 16, 16, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 32)         9248
#  nspose)
#
#  activation_3 (Activation)   (None, 8, 8, 32)          0
#
#  up_sampling2d (UpSampling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_transpose_1 (Conv2DT  (None, 16, 16, 32)       9248
#  ranspose)
#
#  activation_4 (Activation)   (None, 16, 16, 32)        0
#
#  up_sampling2d_1 (UpSampling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 32)       9248
#  ranspose)
#
#  activation_5 (Activation)   (None, 32, 32, 32)        0
#
#  up_sampling2d_2 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 3)         867
#
#  activation_6 (Activation)   (None, 64, 64, 3)         0
#
# =================================================================
# Total params: 48,003
# Trainable params: 48,003
# Non-trainable params: 0
# _________________________________________________________________
# time: 1.29 s (started: 2022-11-20 15:37:59 +00:00)

# %% [markdown]
# ### The below code is for creating training data tfrecord and idx file from images. (We do not use the below code in this jupyter notebook since we import tfrecords directly.)
#
# ```python
# from itertools import islice
# from subprocess import call
#
# def _bytes_feature(value):
#     """Returns a bytes_list from a string / byte."""
#     if isinstance(value, type(tf.constant(0))):
#         value = value.numpy() # BytesList won't unpack a string from an EagerTensor.
#     return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))
#
# #def _float_feature(value):
# #    """Returns a float_list from a float / double."""
# #    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))
#
# def _int64_feature(value):
#     if type(value) != list:
#         value = [value]
#     """Returns an int64_list from a bool / enum / int / uint."""
#     return tf.train.Feature(int64_list=tf.train.Int64List(value=value))
#
# # Create a dictionary with relevant features.
#
# def image_example(image_string, label):
#     image_shape = tf.io.decode_jpeg(image_string).shape
#
#     feature = {
#         'height': _int64_feature(image_shape[0]),
#         'width': _int64_feature(image_shape[1]),
#         'depth': _int64_feature(image_shape[2]),
#         'label': _int64_feature(label),
#         'image_raw': _bytes_feature(image_string),
#     }
#     return tf.train.Example(features=tf.train.Features(feature=feature))
#
# def gen_tfrecord_idx(tfrecord_file, dict_label, tfrecord_idx):
#     with tf.io.TFRecordWriter(tfrecord_file) as writer:
#         for filename, label in dict_label.items():
#             fname = "./image/" + filename
#             image_string = open(fname, 'rb').read()
#             tf_example = image_example(image_string, label)
#             writer.write(tf_example.SerializeToString())
#
#     tfrecord2idx_script = "tfrecord2idx"
#
#     if not os.path.isfile(tfrecord_idx):
#         call([tfrecord2idx_script, tfrecord_file, tfrecord_idx])
#
#
# #--------------------------------------------
# # VALID DATA: Load labels, check headers, check data shape.
#
# df_label_valid = pd.read_csv('label/label_6_basic_emo_valid.csv')
# print("valid columns:", df_label_valid.columns)
# print("valid shape:", df_label_valid.shape)
#
# # Place labels into a dictionary.
#
# dict_label_valid = {}
# for idx, row in df_label_valid.iterrows():
#     dict_label_valid[row['img_id']] = list(row['angry':'sad'].values)
# len(dict_label_valid)
#
# #--------------------------------------------
# # Create VALID tfrecord & idx files from jpg images.
#
# tfrecord_file_valid = './tfrecords/6_basic_emo_valid.tfrecords'
# tfrecord_idx_valid = './tfrecords/6_basic_emo_valid.idx'
#
# gen_tfrecord_idx(tfrecord_file_valid, dict_label_valid, tfrecord_idx_valid)
#
# #--------------------------------------------
# # TRAIN DATA: Load labels, check headers, check data shape.
#
# df_label_train = pd.read_csv('label/label_6_basic_emo_train.csv')
# print("train columns:", df_label_train.columns)
# print("train shape:", df_label_train.shape)
#
# # Place labels into a dictionary.
#
# dict_label_train = {}
# for idx, row in df_label_train.iterrows():
#     dict_label_train[row['img_id']] = list(row['angry':'sad'].values)
# len(dict_label_train)
#
# #--------------------------------------------
# # Create TRAIN tfrecord & idx files from jpg images.
#
# tfrecord_file_train = './tfrecords/6_basic_emo_train.tfrecords'
# tfrecord_idx_train = './tfrecords/6_basic_emo_train.idx'
#
# gen_tfrecord_idx(tfrecord_file_train, dict_label_train, tfrecord_idx_train)
#
# #--------------------------------------------
# # TEST DATA: Load labels, check headers, check data shape.
#
# df_label_test = pd.read_csv('label/label_6_basic_emo_test.csv')
# print("test columns:", df_label_test.columns)
# print("test shape:", df_label_test.shape)
#
# # Place labels into a dictionary.
#
# dict_label_test = {}
# for idx, row in df_label_test.iterrows():
#     dict_label_test[row['img_id']] = list(row['angry':'sad'].values)
# len(dict_label_test)
#
# #-------------------------------------------
# # Create TEST tfrecord & idx files from jpg images.
#
# tfrecord_file_test = './tfrecords/6_basic_emo_test.tfrecords'
# tfrecord_idx_test = './tfrecords/6_basic_emo_test.idx'
#
# gen_tfrecord_idx(tfrecord_file_test, dict_label_test, tfrecord_idx_test)
#
# # OUTPUT
# # valid columns: Index(['img_id', 'clip_id', 'angry', 'disgusted', 'surprised', 'fearful',
# #       'happy', 'sad'],
# #       dtype='object')
# # valid shape: (1282, 8)
# # train columns: Index(['img_id', 'clip_id', 'angry', 'disgusted', 'surprised', 'fearful',
# #       'happy', 'sad'],
# #       dtype='object')
# # train shape: (10249, 8)
# # test columns: Index(['img_id', 'clip_id', 'angry', 'disgusted', 'surprised', 'fearful',
# #       'happy', 'sad'],
# #       dtype='object')
# # test shape: (1282, 8)
# ```

# %% [markdown]
# ### Load label data.

# %%
# Load labels, check headers, check data shape.

df_label = pd.read_csv('/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/label/label_6_basic_emo.csv')
print(df_label.columns)
print(df_label.shape)

LABELS = list(df_label.columns[2:])
print("LABELS=", LABELS)
print("All class:", len(LABELS))

label_valid = pd.read_csv('/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/label/label_6_basic_emo_valid.csv')
label_train = pd.read_csv('/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/label/label_6_basic_emo_train.csv')
label_test = pd.read_csv('/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/label/label_6_basic_emo_test.csv')

VALID_DATA_SIZE = label_valid.shape[0]
TRAIN_DATA_SIZE = label_train.shape[0]
TEST_DATA_SIZE = label_test.shape[0]

print("TRAIN_DATA_SIZE:", label_train.shape[0])
print("VALID_DATA_SIZE:", label_valid.shape[0])
print("TEST_DATA_SIZE:", label_test.shape[0])
# Out:
# Index(['img_id', 'clip_id', 'angry', 'disgusted', 'surprised', 'fearful',
#        'happy', 'sad'],
#       dtype='object')
# (12813, 8)
# LABELS= ['angry', 'disgusted', 'surprised', 'fearful', 'happy', 'sad']
# All class: 6
# TRAIN_DATA_SIZE: 10249
# VALID_DATA_SIZE: 1282
# TEST_DATA_SIZE: 1282
# time: 48.6 ms (started: 2022-11-20 15:38:01 +00:00)

# %% [markdown]
# ### Calculate class weights.

# %%
dict_label_train = {}
for idx, row in label_train.iterrows():
    dict_label_train[row['img_id']] = list(row['angry':'sad'].values)
len(dict_label_train)
# Out:
# 10249
# time: 1.73 s (started: 2022-11-20 15:38:01 +00:00)

# %%
y_train_ls = list(dict_label_train.values())
#y_train_ls
# Out:
# time: 690 µs (started: 2022-11-20 15:38:02 +00:00)

# %%
y_train_ints = [y.index(1) for y in y_train_ls]
# y_train_ints
# Out:
# time: 2.56 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(class_weight ='balanced',
                                                  classes = np.unique(y_train_ints),
                                                  y = y_train_ints)
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: 0.2815040650406504,
#  1: 18.3673835125448,
#  2: 0.7868109933978198,
#  3: 7.6257440476190474,
#  4: 11.46420581655481,
#  5: 1.106325561312608}
# time: 15.3 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
class_weights
# Out:
# array([ 0.28150407, 18.36738351,  0.78681099,  7.62574405, 11.46420582,
#         1.10632556])
# time: 3.82 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
n_samples = len(dict_label_train)
n_classes = len(set(y_train_ints))
# Out:
# time: 825 µs (started: 2022-11-20 15:38:02 +00:00)

# %%
multiplier = 3
adjusted_cw = class_weights / n_classes * multiplier
adjusted_cw
# Out:
# array([0.14075203, 9.18369176, 0.3934055 , 3.81287202, 5.73210291,
#        0.55316278])
# time: 4.54 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
log_weights = n_samples / (n_classes * np.log(np.bincount(y_train_ints)))
sum_weights = sum(log_weights)
sum_weights
custom_class_weights = log_weights / sum_weights
custom_class_weights
# Out:
# array([0.11638164, 0.22366313, 0.13195144, 0.18733217, 0.20259518,
#        0.13807644])
# time: 9.98 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
custom_class_weights += adjusted_cw
custom_class_weights
# Out:
# array([0.25713368, 9.40735489, 0.52535693, 4.00020419, 5.93469809,
#        0.69123922])
# time: 3.46 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
class_weight_dict = dict(enumerate(custom_class_weights))
class_weight_dict
# Out:
# {0: 0.25713367600252574,
#  1: 9.407354888012607,
#  2: 0.5253569344678802,
#  3: 4.0002041936980595,
#  4: 5.934698087278068,
#  5: 0.6912392187757267}
# time: 3.67 ms (started: 2022-11-20 15:38:02 +00:00)

# %% [markdown]
# ### Define training pipeline.

# %%
# !nvidia-smi
# Out:
# Sun Nov 20 15:38:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    29W /  70W |    314MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# time: 160 ms (started: 2022-11-20 15:38:02 +00:00)

# %%
#https://docs.nvidia.com/deeplearning/dali/user-guide/docs/installation.html
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist --upgrade nvidia-dali-cuda102
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist --upgrade nvidia-dali-tf-plugin-cuda102
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://developer.download.nvidia.com/compute/redist
# Requirement already satisfied: nvidia-dali-cuda102 in /usr/local/lib/python3.7/dist-packages (1.19.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://developer.download.nvidia.com/compute/redist
# Requirement already satisfied: nvidia-dali-tf-plugin-cuda102 in /usr/local/lib/python3.7/dist-packages (1.19.0)
# Requirement already satisfied: nvidia-dali-cuda102==1.19.0 in /usr/local/lib/python3.7/dist-packages (from nvidia-dali-tf-plugin-cuda102) (1.19.0)
# time: 12.8 s (started: 2022-11-20 15:38:03 +00:00)

# %%
from nvidia.dali.pipeline import Pipeline
import nvidia.dali.fn as fn
import nvidia.dali.types as types
import nvidia.dali.tfrecord as tfrec
import nvidia.dali.plugin.tf as dali_tf

class TFRecordPipelineTrain(Pipeline):
    def __init__(self, batch_size, num_threads,
                 device = 'cpu', device_id = 0):
        super(TFRecordPipelineTrain, self).__init__(batch_size,
                                         num_threads,
                                         device_id)
        self.input = fn.readers.tfrecord(        
             features = {"image_raw": tfrec.FixedLenFeature((), tfrec.string, ""),
                         "label": tfrec.FixedLenFeature([6], tfrec.int64,  6)},
             path = ['/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/tfrecords/6_basic_emo_train.tfrecords'],
             index_path = ['/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/tfrecords/6_basic_emo_train.idx'],
             random_shuffle=True,
             seed = set_seed)
        self.iter = 0
    def define_graph(self):
        inputs = self.input
        images = fn.decoders.image(inputs["image_raw"], device = "mixed", output_type = types.RGB) / 255.
        labels = inputs["label"].gpu()
        return (images, labels)
    def iter_setup(self):
        pass
# Out:
# time: 168 ms (started: 2022-11-20 15:38:15 +00:00)
# /usr/local/lib/python3.7/dist-packages/nvidia/dali/backend.py:51: Warning: DALI plans to drop the support for CUDA 10.2 in the upcoming releases. Please update your CUDA toolkit.
#   "DALI plans to drop the support for CUDA 10.2 in the upcoming releases. "

# %% [markdown]
# ### Define validation pipeline.

# %%
class TFRecordPipelineValid(Pipeline):
    def __init__(self, batch_size, num_threads,
                 device = 'cpu', device_id = 0):
        super(TFRecordPipelineValid, self).__init__(batch_size,
                                         num_threads,
                                         device_id)
        self.input = fn.readers.tfrecord(        
             features = {"image_raw": tfrec.FixedLenFeature((), tfrec.string, ""),
                         "label": tfrec.FixedLenFeature([6], tfrec.int64,  6)},
             path = ['/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/tfrecords/6_basic_emo_valid.tfrecords'],
             index_path = ['/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/tfrecords/6_basic_emo_valid.idx'],
             random_shuffle=False,
             seed = set_seed)
        self.iter = 0
    def define_graph(self):
        inputs = self.input
        images = fn.decoders.image(inputs["image_raw"], device = "mixed", output_type = types.RGB) / 255.
        labels = inputs["label"].gpu()
        return (images, labels)
    def iter_setup(self):
        pass
# Out:
# time: 15 ms (started: 2022-11-20 15:38:16 +00:00)

# %% [markdown]
# ### Train autoencoder model for classifying 6 basic emotions.

# %%
if __name__ == "__main__":
    batch_size = 64
    shapes = ((batch_size, 64, 64, 3),
              (batch_size, 6))
    pipe_train = TFRecordPipelineTrain(batch_size=batch_size, 
                                 num_threads=1, 
                                 device='gpu', 
                                 device_id=0)
    
    batch_size_valid = 64
    shapes_valid = ((batch_size_valid, 64, 64, 3),
              (batch_size_valid, 6))
    pipe_valid = TFRecordPipelineValid(batch_size=batch_size_valid, 
                                 num_threads=1, 
                                 device='gpu', 
                                 device_id=0)    

    with tf.device('/gpu:0'):
        ds_train = dali_tf.DALIDataset(
            pipeline=pipe_train,
            batch_size=batch_size,
            output_shapes=shapes,
            output_dtypes=(tf.float32, tf.int64),
            device_id=0)
        
        ds_valid = dali_tf.DALIDataset(
            pipeline=pipe_valid,
            batch_size=batch_size_valid,
            output_shapes=shapes_valid,
            output_dtypes=(tf.float32, tf.int64),
            device_id=0)     
       
        initializer = keras.initializers.GlorotUniform(seed=set_seed)
        activation =  keras.activations.softmax
        lr_schedule = keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=1e-5,
            decay_steps=TRAIN_DATA_SIZE // batch_size * 10,
            decay_rate=0.95)

        number_of_classes = 6
        
        inputs = keras.Input(shape=(64, 64, 3))
        x = autoencoder(inputs, training=False)   # Fix autoencoder weights.
        flat = keras.layers.Flatten()(x)
        fc1 = keras.layers.Dense(number_of_classes, activation='relu',
                             kernel_initializer=initializer)(flat)
        do1 = keras.layers.Dropout(0.5, seed=set_seed)(fc1)    
        outputs = keras.layers.Dense(number_of_classes,
                             kernel_initializer=initializer,
                             activation=activation)(do1) 
        clf = keras.Model(inputs, outputs)
        
        clf.summary()
        
        # To save the model weights, uncomment the below code.        
        #checkpoint_path = "./model/cp_clf_6_emo.ckpt"
        #cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
        #                                         save_weights_only=True,
        #                                         verbose=1)
        
        # Apply early stopping.        
        es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10,
                                                       restore_best_weights=True)
       
        clf.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
              loss=keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
        
        history = clf.fit(ds_train, steps_per_epoch=TRAIN_DATA_SIZE // batch_size,
                          validation_data=ds_valid.take(VALID_DATA_SIZE // batch_size_valid),
                          epochs=1000,
                          class_weight=class_weight_dict,
                          )#callbacks=[es_callback])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#
1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9805 - accuracy: 0.5543 - val_loss: 1.6229 - val_accuracy: 0.5141
# Epoch 117/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 1.0057 - accuracy: 0.5525 - val_loss: 1.6079 - val_accuracy: 0.5328
# Epoch 118/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9917 - accuracy: 0.5583 - val_loss: 1.6089 - val_accuracy: 0.5227
# Epoch 119/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9912 - accuracy: 0.5560 - val_loss: 1.6032 - val_accuracy: 0.5461
# Epoch 120/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9823 - accuracy: 0.5647 - val_loss: 1.6113 - val_accuracy: 0.5242
# Epoch 121/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9913 - accuracy: 0.5532 - val_loss: 1.6023 - val_accuracy: 0.5320
# Epoch 122/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9919 - accuracy: 0.5562 - val_loss: 1.6042 - val_accuracy: 0.5242
# Epoch 123/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9887 - accuracy: 0.5552 - val_loss: 1.5951 - val_accuracy: 0.5523
# Epoch 124/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9994 - accuracy: 0.5582 - val_loss: 1.5977 - val_accuracy: 0.5406
# Epoch 125/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9801 - accuracy: 0.5559 - val_loss: 1.6009 - val_accuracy: 0.5266
# Epoch 126/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9929 - accuracy: 0.5570 - val_loss: 1.5952 - val_accuracy: 0.5352
# Epoch 127/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9913 - accuracy: 0.5583 - val_loss: 1.5936 - val_accuracy: 0.5500
# Epoch 128/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9856 - accuracy: 0.5614 - val_loss: 1.5926 - val_accuracy: 0.5430
# Epoch 129/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9907 - accuracy: 0.5574 - val_loss: 1.5980 - val_accuracy: 0.5367
# Epoch 130/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9936 - accuracy: 0.5595 - val_loss: 1.6017 - val_accuracy: 0.5320
# Epoch 131/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9800 - accuracy: 0.5594 - val_loss: 1.5949 - val_accuracy: 0.5383
# Epoch 132/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9834 - accuracy: 0.5575 - val_loss: 1.6018 - val_accuracy: 0.5367
# Epoch 133/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9815 - accuracy: 0.5626 - val_loss: 1.5957 - val_accuracy: 0.5367
# Epoch 134/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9861 - accuracy: 0.5547 - val_loss: 1.5892 - val_accuracy: 0.5398
# Epoch 135/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9893 - accuracy: 0.5662 - val_loss: 1.5954 - val_accuracy: 0.5367
# Epoch 136/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9787 - accuracy: 0.5589 - val_loss: 1.5877 - val_accuracy: 0.5344
# Epoch 137/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9784 - accuracy: 0.5599 - val_loss: 1.6006 - val_accuracy: 0.5367
# Epoch 138/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9758 - accuracy: 0.5628 - val_loss: 1.5884 - val_accuracy: 0.5367
# Epoch 139/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9742 - accuracy: 0.5584 - val_loss: 1.5854 - val_accuracy: 0.5437
# Epoch 140/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9859 - accuracy: 0.5613 - val_loss: 1.5884 - val_accuracy: 0.5320
# Epoch 141/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9725 - accuracy: 0.5644 - val_loss: 1.5866 - val_accuracy: 0.5320
# Epoch 142/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9907 - accuracy: 0.5532 - val_loss: 1.5946 - val_accuracy: 0.5180
# Epoch 143/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9640 - accuracy: 0.5612 - val_loss: 1.5849 - val_accuracy: 0.5398
# Epoch 144/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9743 - accuracy: 0.5635 - val_loss: 1.5808 - val_accuracy: 0.5406
# Epoch 145/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9907 - accuracy: 0.5594 - val_loss: 1.5896 - val_accuracy: 0.5227
# Epoch 146/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9772 - accuracy: 0.5585 - val_loss: 1.5850 - val_accuracy: 0.5367
# Epoch 147/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.
1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9759 - accuracy: 0.5621 - val_loss: 1.5602 - val_accuracy: 0.5586
# Epoch 179/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9601 - accuracy: 0.5708 - val_loss: 1.5592 - val_accuracy: 0.5578
# Epoch 180/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9746 - accuracy: 0.5620 - val_loss: 1.5532 - val_accuracy: 0.5586
# Epoch 181/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9695 - accuracy: 0.5644 - val_loss: 1.5513 - val_accuracy: 0.5656
# Epoch 182/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9656 - accuracy: 0.5689 - val_loss: 1.5560 - val_accuracy: 0.5617
# Epoch 183/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9570 - accuracy: 0.5691 - val_loss: 1.5540 - val_accuracy: 0.5570
# Epoch 184/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9664 - accuracy: 0.5656 - val_loss: 1.5633 - val_accuracy: 0.5492
# Epoch 185/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9788 - accuracy: 0.5653 - val_loss: 1.5488 - val_accuracy: 0.5641
# Epoch 186/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9727 - accuracy: 0.5652 - val_loss: 1.5546 - val_accuracy: 0.5609
# Epoch 187/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9646 - accuracy: 0.5702 - val_loss: 1.5486 - val_accuracy: 0.5633
# Epoch 188/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9779 - accuracy: 0.5678 - val_loss: 1.5489 - val_accuracy: 0.5555
# Epoch 189/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9581 - accuracy: 0.5643 - val_loss: 1.5615 - val_accuracy: 0.5547
# Epoch 190/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9651 - accuracy: 0.5634 - val_loss: 1.5561 - val_accuracy: 0.5586
# Epoch 191/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9407 - accuracy: 0.5700 - val_loss: 1.5453 - val_accuracy: 0.5609
# Epoch 192/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9665 - accuracy: 0.5649 - val_loss: 1.5496 - val_accuracy: 0.5633
# Epoch 193/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9755 - accuracy: 0.5589 - val_loss: 1.5473 - val_accuracy: 0.5594
# Epoch 194/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9632 - accuracy: 0.5635 - val_loss: 1.5561 - val_accuracy: 0.5508
# Epoch 195/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9709 - accuracy: 0.5668 - val_loss: 1.5512 - val_accuracy: 0.5641
# Epoch 196/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9547 - accuracy: 0.5699 - val_loss: 1.5422 - val_accuracy: 0.5680
# Epoch 197/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9538 - accuracy: 0.5650 - val_loss: 1.5395 - val_accuracy: 0.5641
# Epoch 198/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9640 - accuracy: 0.5646 - val_loss: 1.5497 - val_accuracy: 0.5625
# Epoch 199/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9766 - accuracy: 0.5662 - val_loss: 1.5458 - val_accuracy: 0.5688
# Epoch 200/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9562 - accuracy: 0.5655 - val_loss: 1.5520 - val_accuracy: 0.5625
# Epoch 201/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9715 - accuracy: 0.5649 - val_loss: 1.5512 - val_accuracy: 0.5641
# Epoch 202/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9721 - accuracy: 0.5684 - val_loss: 1.5453 - val_accuracy: 0.5672
# Epoch 203/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9538 - accuracy: 0.5739 - val_loss: 1.5359 - val_accuracy: 0.5711
# Epoch 204/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9797 - accuracy: 0.5690 - val_loss: 1.5509 - val_accuracy: 0.5594
# Epoch 205/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9445 - accuracy: 0.5681 - val_loss: 1.5420 - val_accuracy: 0.5617
# Epoch 206/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9688 - accuracy: 0.5629 - val_loss: 1.5460 - val_accuracy: 0.5664
# Epoch 207/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9576 - accuracy: 0.5699 - val_loss: 1.5373 - val_accuracy: 0.5633
# Epoch 208/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9691 - accuracy: 0.5725 - val_loss: 1.5379 - val_accuracy: 0.5695
# Epoch 209/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9535 - accuracy: 0.5701 - val_loss: 1.5401 - val_accuracy: 0.5617
# Epoch 210/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9691 - accuracy: 0.5685 - val_loss: 1.5442 - val_accuracy: 0.5633
# Epoch 211/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9477 - accuracy: 0.5732 - val_loss: 1.5465 - val_accuracy: 0.5617
# Epoch 212/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9607 - accuracy: 0.5704 - val_loss: 1.5469 - val_accuracy: 0.5586
# Epoch 213/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9665 - accuracy: 0.5668 - val_loss: 1.5457 - val_accuracy: 0.5719
# Epoch 214/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9491 - accuracy: 0.5713 - val_loss: 1.5423 - val_accuracy: 0.5641
# Epoch 215/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9585 - accuracy: 0.5759 - val_loss: 1.5391 - val_accuracy: 0.5672
# Epoch 216/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9616 - accuracy: 0.5679 - val_loss: 1.5348 - val_accuracy: 0.5734
# Epoch 217/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9580 - accuracy: 0.5771 - val_loss: 1.5309 - val_accuracy: 0.5766
# Epoch 218/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9713 - accuracy: 0.5704 - val_loss: 1.5450 - val_accuracy: 0.5641
# Epoch 219/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9497 - accuracy: 0.5668 - val_loss: 1.5415 - val_accuracy: 0.5625
# Epoch 220/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9420 - accuracy: 0.5740 - val_loss: 1.5406 - val_accuracy: 0.5680
# Epoch 221/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9584 - accuracy: 0.5722 - val_loss: 1.5321 - val_accuracy: 0.5719
# Epoch 222/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9505 - accuracy: 0.5725 - val_loss: 1.5354 - val_accuracy: 0.5711
# Epoch 223/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9595 - accuracy: 0.5744 - val_loss: 1.5309 - val_accuracy: 0.5688
# Epoch 224/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9763 - accuracy: 0.5683 - val_loss: 1.5354 - val_accuracy: 0.5727
# Epoch 225/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9480 - accuracy: 0.5725 - val_loss: 1.5303 - val_accuracy: 0.5742
# Epoch 226/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9569 - accuracy: 0.5763 - val_loss: 1.5261 - val_accuracy: 0.5742
# Epoch 227/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9511 - accuracy: 0.5693 - val_loss: 1.5331 - val_accuracy: 0.5703
# Epoch 228/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9445 - accuracy: 0.5759 - val_loss: 1.5301 - val_accuracy: 0.5813
# Epoch 229/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9563 - accuracy: 0.5707 - val_loss: 1.5302 - val_accuracy: 0.5711
# Epoch 230/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9347 - accuracy: 0.5778 - val_loss: 1.5271 - val_accuracy: 0.5781
# Epoch 231/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9596 - accuracy: 0.5792 - val_loss: 1.5380 - val_accuracy: 0.5648
# Epoch 232/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9554 - accuracy: 0.5708 - val_loss: 1.5287 - val_accuracy: 0.5680
# Epoch 233/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9532 - accuracy: 0.5688 - val_loss: 1.5358 - val_accuracy: 0.5617
# Epoch 234/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9553 - accuracy: 0.5722 - val_loss: 1.5302 - val_accuracy: 0.5711
# Epoch 235/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9559 - accuracy: 0.5699 - val_loss: 1.5210 - val_accuracy: 0.5813
# Epoch 236/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9510 - accuracy: 0.5743 - val_loss: 1.5287 - val_accuracy: 0.5703
# Epoch 237/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9482 - accuracy: 0.5764 - val_loss: 1.5320 - val_accuracy: 0.5742
# Epoch 238/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9536 - accuracy: 0.5734 - val_loss: 1.5293 - val_accuracy: 0.5719
# Epoch 239/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9488 - accuracy: 0.5726 - val_loss: 1.5257 - val_accuracy: 0.5695
# Epoch 240/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9467 - accuracy: 0.5724 - val_loss: 1.5202 - val_accuracy: 0.5719
# Epoch 241/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9360 - accuracy: 0.5762 - val_loss: 1.5263 - val_accuracy: 0.5742
# Epoch 242/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9536 - accuracy: 0.5716 - val_loss: 1.5333 - val_accuracy: 0.5656
# Epoch 243/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9435 - accuracy: 0.5731 - val_loss: 1.5353 - val_accuracy: 0.5680
# Epoch 244/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9537 - accuracy: 0.5771 - val_loss: 1.5302 - val_accuracy: 0.5711
# Epoch 245/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9419 - accuracy: 0.5718 - val_loss: 1.5223 - val_accuracy: 0.5781
# Epoch 246/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9593 - accuracy: 0.5737 - val_loss: 1.5304 - val_accuracy: 0.5734
# Epoch 247/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9478 - accuracy: 0.5724 - val_loss: 1.5306 - val_accuracy: 0.5766
# Epoch 248/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9591 - accuracy: 0.5700 - val_loss: 1.5196 - val_accuracy: 0.5781
# Epoch 249/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9572 - accuracy: 0.5676 - val_loss: 1.5309 - val_accuracy: 0.5805
# Epoch 250/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9594 - accuracy: 0.5736 - val_loss: 1.5236 - val_accuracy: 0.5750
# Epoch 251/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9574 - accuracy: 0.5781 - val_loss: 1.5260 - val_accuracy: 0.5719
# Epoch 252/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9502 - accuracy: 0.5744 - val_loss: 1.5225 - val_accuracy: 0.5859
# Epoch 253/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9521 - accuracy: 0.5719 - val_loss: 1.5216 - val_accuracy: 0.5789
# Epoch 254/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9464 - accuracy: 0.5729 - val_loss: 1.5183 - val_accuracy: 0.5781
# Epoch 255/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9486 - accuracy: 0.5720 - val_loss: 1.5233 - val_accuracy: 0.5688
# Epoch 256/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9477 - accuracy: 0.5749 - val_loss: 1.5236 - val_accuracy: 0.5820
# Epoch 257/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9625 - accuracy: 0.5715 - val_loss: 1.5225 - val_accuracy: 0.5883
# Epoch 258/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9350 - accuracy: 0.5786 - val_loss: 1.5242 - val_accuracy: 0.5797
# Epoch 259/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9497 - accuracy: 0.5702 - val_loss: 1.5183 - val_accuracy: 0.5797
# Epoch 260/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9488 - accuracy: 0.5736 - val_loss: 1.5164 - val_accuracy: 0.5766
# Epoch 261/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9404 - accuracy: 0.5755 - val_loss: 1.5250 - val_accuracy: 0.5828
# Epoch 262/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9497 - accuracy: 0.5738 - val_loss: 1.5137 - val_accuracy: 0.5828
# Epoch 263/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9550 - accuracy: 0.5710 - val_loss: 1.5146 - val_accuracy: 0.5805
# Epoch 264/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9510 - accuracy: 0.5764 - val_loss: 1.5186 - val_accuracy: 0.5703
# Epoch 265/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9445 - accuracy: 0.5711 - val_loss: 1.5205 - val_accuracy: 0.5773
# Epoch 266/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9529 - accuracy: 0.5705 - val_loss: 1.5164 - val_accuracy: 0.5828
# Epoch 267/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9352 - accuracy: 0.5760 - val_loss: 1.5192 - val_accuracy: 0.5750
# Epoch 268/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9579 - accuracy: 0.5737 - val_loss: 1.5155 - val_accuracy: 0.5789
# Epoch 269/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9334 - accuracy: 0.5761 - val_loss: 1.5180 - val_accuracy: 0.5789
# Epoch 270/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9493 - accuracy: 0.5727 - val_loss: 1.5165 - val_accuracy: 0.5734
# Epoch 271/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9528 - accuracy: 0.5759 - val_loss: 1.5195 - val_accuracy: 0.5766
# Epoch 272/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9472 - accuracy: 0.5746 - val_loss: 1.5161 - val_accuracy: 0.5742
# Epoch 273/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.
1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9466 - accuracy: 0.5716 - val_loss: 1.5021 - val_accuracy: 0.5773
# Epoch 304/1000
# 160/160 [==============================] - 4s 22ms/step - loss: 0.9410 - accuracy: 0.5783 - val_loss: 1.5071 - val_accuracy: 0.5742
# Epoch 305/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9394 - accuracy: 0.5771 - val_loss: 1.5072 - val_accuracy: 0.5773
# Epoch 306/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9503 - accuracy: 0.5733 - val_loss: 1.5024 - val_accuracy: 0.5758
# Epoch 307/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9422 - accuracy: 0.5745 - val_loss: 1.5040 - val_accuracy: 0.5742
# Epoch 308/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9335 - accuracy: 0.5790 - val_loss: 1.5028 - val_accuracy: 0.5742
# Epoch 309/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9504 - accuracy: 0.5812 - val_loss: 1.5008 - val_accuracy: 0.5742
# Epoch 310/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9392 - accuracy: 0.5728 - val_loss: 1.5061 - val_accuracy: 0.5836
# Epoch 311/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9374 - accuracy: 0.5766 - val_loss: 1.5078 - val_accuracy: 0.5789
# Epoch 312/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9374 - accuracy: 0.5765 - val_loss: 1.4984 - val_accuracy: 0.5797
# Epoch 313/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9480 - accuracy: 0.5780 - val_loss: 1.5007 - val_accuracy: 0.5797
# Epoch 314/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9455 - accuracy: 0.5760 - val_loss: 1.4968 - val_accuracy: 0.5813
# Epoch 315/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9406 - accuracy: 0.5778 - val_loss: 1.5069 - val_accuracy: 0.5742
# Epoch 316/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9388 - accuracy: 0.5840 - val_loss: 1.4993 - val_accuracy: 0.5867
# Epoch 317/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9560 - accuracy: 0.5749 - val_loss: 1.5009 - val_accuracy: 0.5828
# Epoch 318/1000
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9457 - accuracy: 0.5779 - val_loss: 1.5034 - val_accuracy: 0.5781
# Epoch 319/1000
# 160/160 [==============================] - 3s 22ms/step - loss: 0.9458 - accuracy: 0.5776 - val_loss: 1.5058 - val_accuracy: 0.5836
# ...
# Epoch 893/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9125 - accuracy: 0.5887 - val_loss: 1.4543 - val_accuracy: 0.6000
# Epoch 894/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9445 - accuracy: 0.5889 - val_loss: 1.4542 - val_accuracy: 0.6008
# Epoch 895/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9242 - accuracy: 0.5922 - val_loss: 1.4537 - val_accuracy: 0.6008
# Epoch 896/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9273 - accuracy: 0.5839 - val_loss: 1.4544 - val_accuracy: 0.6000
# Epoch 897/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9242 - accuracy: 0.5888 - val_loss: 1.4545 - val_accuracy: 0.5992
# Epoch 898/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9197 - accuracy: 0.5860 - val_loss: 1.4537 - val_accuracy: 0.6008
# Epoch 899/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9285 - accuracy: 0.5857 - val_loss: 1.4539 - val_accuracy: 0.5992
# Epoch 900/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9176 - accuracy: 0.5883 - val_loss: 1.4543 - val_accuracy: 0.6000
# Epoch 901/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9350 - accuracy: 0.5881 - val_loss: 1.4539 - val_accuracy: 0.5992
# Epoch 902/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9230 - accuracy: 0.5916 - val_loss: 1.4537 - val_accuracy: 0.5977
# Epoch 903/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9352 - accuracy: 0.5860 - val_loss: 1.4533 - val_accuracy: 0.5984
# Epoch 904/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9164 - accuracy: 0.5884 - val_loss: 1.4533 - val_accuracy: 0.6000
# Epoch 905/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9251 - accuracy: 0.5896 - val_loss: 1.4534 - val_accuracy: 0.6008
# Epoch 906/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9365 - accuracy: 0.5858 - val_loss: 1.4532 - val_accuracy: 0.6000
# Epoch 907/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9097 - accuracy: 0.5938 - val_loss: 1.4535 - val_accuracy: 0.6008
# Epoch 908/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9268 - accuracy: 0.5872 - val_loss: 1.4539 - val_accuracy: 0.6008
# Epoch 909/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9231 - accuracy: 0.5871 - val_loss: 1.4538 - val_accuracy: 0.6000
# Epoch 910/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9173 - accuracy: 0.5831 - val_loss: 1.4538 - val_accuracy: 0.6000
# Epoch 911/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9254 - accuracy: 0.5855 - val_loss: 1.4539 - val_accuracy: 0.6000
# Epoch 912/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9164 - accuracy: 0.5838 - val_loss: 1.4541 - val_accuracy: 0.5992
# Epoch 913/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9221 - accuracy: 0.5905 - val_loss: 1.4543 - val_accuracy: 0.5977
# Epoch 914/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9324 - accuracy: 0.5875 - val_loss: 1.4540 - val_accuracy: 0.5992
# Epoch 915/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9254 - accuracy: 0.5847 - val_loss: 1.4539 - val_accuracy: 0.6000
# Epoch 916/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9204 - accuracy: 0.5843 - val_loss: 1.4541 - val_accuracy: 0.5992
# Epoch 917/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9182 - accuracy: 0.5875 - val_loss: 1.4540 - val_accuracy: 0.6000
# Epoch 918/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9368 - accuracy: 0.5870 - val_loss: 1.4535 - val_accuracy: 0.6008
# Epoch 919/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9026 - accuracy: 0.5860 - val_loss: 1.4535 - val_accuracy: 0.6008
# Epoch 920/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9147 - accuracy: 0.5906 - val_loss: 1.4538 - val_accuracy: 0.6000
# Epoch 921/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9163 - accuracy: 0.5880 - val_loss: 1.4537 - val_accuracy: 0.5992
# Epoch 922/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9211 - accuracy: 0.5873 - val_loss: 1.4534 - val_accuracy: 0.5992
# Epoch 923/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9157 - accuracy: 0.5878 - val_loss: 1.4531 - val_accuracy: 0.5992
# Epoch 924/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9170 - accuracy: 0.5894 - val_loss: 1.4533 - val_accuracy: 0.5984
# Epoch 925/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9360 - accuracy: 0.5849 - val_loss: 1.4539 - val_accuracy: 0.5984
# Epoch 926/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9181 - accuracy: 0.5935 - val_loss: 1.4535 - val_accuracy: 0.5984
# Epoch 927/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9330 - accuracy: 0.5881 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 928/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9283 - accuracy: 0.5830 - val_loss: 1.4536 - val_accuracy: 0.6000
# Epoch 929/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9225 - accuracy: 0.5912 - val_loss: 1.4538 - val_accuracy: 0.5992
# Epoch 930/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9140 - accuracy: 0.5859 - val_loss: 1.4538 - val_accuracy: 0.5992
# Epoch 931/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9290 - accuracy: 0.5885 - val_loss: 1.4538 - val_accuracy: 0.6000
# Epoch 932/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9336 - accuracy: 0.5855 - val_loss: 1.4533 - val_accuracy: 0.5992
# Epoch 933/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9195 - accuracy: 0.5916 - val_loss: 1.4533 - val_accuracy: 0.5992
# Epoch 934/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9312 - accuracy: 0.5867 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 935/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9314 - accuracy: 0.5867 - val_loss: 1.4533 - val_accuracy: 0.6000
# Epoch 936/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9289 - accuracy: 0.5892 - val_loss: 1.4535 - val_accuracy: 0.6008
# Epoch 937/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9134 - accuracy: 0.5915 - val_loss: 1.4535 - val_accuracy: 0.6008
# Epoch 938/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9310 - accuracy: 0.5869 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 939/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9382 - accuracy: 0.5883 - val_loss: 1.4536 - val_accuracy: 0.6000
# Epoch 940/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9387 - accuracy: 0.5861 - val_loss: 1.4536 - val_accuracy: 0.5992
# Epoch 941/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9078 - accuracy: 0.5885 - val_loss: 1.4536 - val_accuracy: 0.6008
# Epoch 942/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9314 - accuracy: 0.5866 - val_loss: 1.4538 - val_accuracy: 0.6000
# Epoch 943/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9285 - accuracy: 0.5943 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 944/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9171 - accuracy: 0.5832 - val_loss: 1.4534 - val_accuracy: 0.5984
# Epoch 945/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9291 - accuracy: 0.5854 - val_loss: 1.4536 - val_accuracy: 0.6000
# Epoch 946/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9221 - accuracy: 0.5902 - val_loss: 1.4536 - val_accuracy: 0.6000
# Epoch 947/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9281 - accuracy: 0.5830 - val_loss: 1.4532 - val_accuracy: 0.6000
# Epoch 948/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9264 - accuracy: 0.5903 - val_loss: 1.4536 - val_accuracy: 0.5992
# Epoch 949/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9321 - accuracy: 0.5860 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 950/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9336 - accuracy: 0.5871 - val_loss: 1.4534 - val_accuracy: 0.6000
# Epoch 951/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9129 - accuracy: 0.5886 - val_loss: 1.4533 - val_accuracy: 0.6000
# Epoch 952/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9252 - accuracy: 0.5858 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 953/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9204 - accuracy: 0.5938 - val_loss: 1.4540 - val_accuracy: 0.6000
# Epoch 954/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9161 - accuracy: 0.5844 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 955/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9284 - accuracy: 0.5907 - val_loss: 1.4536 - val_accuracy: 0.6000
# Epoch 956/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9173 - accuracy: 0.5868 - val_loss: 1.4539 - val_accuracy: 0.6000
# Epoch 957/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9273 - accuracy: 0.5882 - val_loss: 1.4533 - val_accuracy: 0.5984
# Epoch 958/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9236 - accuracy: 0.5890 - val_loss: 1.4534 - val_accuracy: 0.6000
# Epoch 959/1000
# 160/160 [==============================] - 4s 22ms/step - loss: 0.9282 - accuracy: 0.5899 - val_loss: 1.4534 - val_accuracy: 0.6008
# Epoch 960/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9472 - accuracy: 0.5892 - val_loss: 1.4537 - val_accuracy: 0.6008
# Epoch 961/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9126 - accuracy: 0.5885 - val_loss: 1.4531 - val_accuracy: 0.5992
# Epoch 962/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9268 - accuracy: 0.5831 - val_loss: 1.4534 - val_accuracy: 0.6000
# Epoch 963/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9270 - accuracy: 0.5904 - val_loss: 1.4535 - val_accuracy: 0.5984
# Epoch 964/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9251 - accuracy: 0.5884 - val_loss: 1.4534 - val_accuracy: 0.5984
# Epoch 965/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9170 - accuracy: 0.5892 - val_loss: 1.4530 - val_accuracy: 0.5984
# Epoch 966/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9341 - accuracy: 0.5881 - val_loss: 1.4532 - val_accuracy: 0.5984
# Epoch 967/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9156 - accuracy: 0.5920 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 968/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9307 - accuracy: 0.5858 - val_loss: 1.4530 - val_accuracy: 0.6000
# Epoch 969/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9210 - accuracy: 0.5889 - val_loss: 1.4532 - val_accuracy: 0.6000
# Epoch 970/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9148 - accuracy: 0.5897 - val_loss: 1.4532 - val_accuracy: 0.6000
# Epoch 971/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9347 - accuracy: 0.5865 - val_loss: 1.4532 - val_accuracy: 0.6000
# Epoch 972/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9113 - accuracy: 0.5921 - val_loss: 1.4530 - val_accuracy: 0.5992
# Epoch 973/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9208 - accuracy: 0.5914 - val_loss: 1.4535 - val_accuracy: 0.6000
# Epoch 974/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9310 - accuracy: 0.5846 - val_loss: 1.4532 - val_accuracy: 0.5992
# Epoch 975/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9218 - accuracy: 0.5910 - val_loss: 1.4534 - val_accuracy: 0.6000
# Epoch 976/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9234 - accuracy: 0.5896 - val_loss: 1.4529 - val_accuracy: 0.6000
# Epoch 977/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9313 - accuracy: 0.5901 - val_loss: 1.4529 - val_accuracy: 0.5984
# Epoch 978/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9156 - accuracy: 0.5882 - val_loss: 1.4527 - val_accuracy: 0.5984
# Epoch 979/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9133 - accuracy: 0.5838 - val_loss: 1.4527 - val_accuracy: 0.5984
# Epoch 980/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9417 - accuracy: 0.5865 - val_loss: 1.4531 - val_accuracy: 0.5984
# Epoch 981/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9321 - accuracy: 0.5861 - val_loss: 1.4531 - val_accuracy: 0.5984
# Epoch 982/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9276 - accuracy: 0.5881 - val_loss: 1.4532 - val_accuracy: 0.6008
# Epoch 983/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9316 - accuracy: 0.5916 - val_loss: 1.4531 - val_accuracy: 0.6000
# Epoch 984/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9211 - accuracy: 0.5880 - val_loss: 1.4530 - val_accuracy: 0.5992
# Epoch 985/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9102 - accuracy: 0.5904 - val_loss: 1.4531 - val_accuracy: 0.6000
# Epoch 986/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9201 - accuracy: 0.5893 - val_loss: 1.4532 - val_accuracy: 0.5992
# Epoch 987/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9198 - accuracy: 0.5890 - val_loss: 1.4530 - val_accuracy: 0.5984
# Epoch 988/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9329 - accuracy: 0.5879 - val_loss: 1.4531 - val_accuracy: 0.6008
# Epoch 989/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9190 - accuracy: 0.5882 - val_loss: 1.4529 - val_accuracy: 0.5984
# Epoch 990/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9293 - accuracy: 0.5871 - val_loss: 1.4531 - val_accuracy: 0.6008
# Epoch 991/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9186 - accuracy: 0.5875 - val_loss: 1.4532 - val_accuracy: 0.5984
# Epoch 992/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9239 - accuracy: 0.5873 - val_loss: 1.4528 - val_accuracy: 0.5984
# Epoch 993/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9113 - accuracy: 0.5889 - val_loss: 1.4531 - val_accuracy: 0.5984
# Epoch 994/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9279 - accuracy: 0.5871 - val_loss: 1.4532 - val_accuracy: 0.5984
# Epoch 995/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9309 - accuracy: 0.5894 - val_loss: 1.4532 - val_accuracy: 0.5992
# Epoch 996/1000
# 160/160 [==============================] - 4s 23ms/step - loss: 0.9252 - accuracy: 0.5916 - val_loss: 1.4529 - val_accuracy: 0.6008
# Epoch 997/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9336 - accuracy: 0.5859 - val_loss: 1.4529 - val_accuracy: 0.6008
# Epoch 998/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9398 - accuracy: 0.5864 - val_loss: 1.4528 - val_accuracy: 0.6000
# Epoch 999/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9147 - accuracy: 0.5875 - val_loss: 1.4528 - val_accuracy: 0.5992
# Epoch 1000/1000
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9069 - accuracy: 0.5886 - val_loss: 1.4529 - val_accuracy: 0.5992
# time: 59min 9s (started: 2022-11-20 15:38:16 +00:00)

# %%
# List all data in history.

print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# time: 768 µs (started: 2022-11-20 16:37:25 +00:00)

# %%
# Summarize history for accuracy.

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy (test data)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
# Out:
# time: 132 ms (started: 2022-11-20 16:37:25 +00:00)

# %%
# Summarize history for loss.

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()
# Out:
# time: 126 ms (started: 2022-11-20 16:37:26 +00:00)

# %% [markdown]
# ### Define test pipeline.

# %%
class TFRecordPipelineTest(Pipeline):
    def __init__(self, batch_size, num_threads,
                 device = 'cpu', device_id = 0):
        super(TFRecordPipelineTest, self).__init__(batch_size,
                                         num_threads,
                                         device_id)
        self.input = fn.readers.tfrecord(        
             features = {"image_raw": tfrec.FixedLenFeature((), tfrec.string, ""),
                         "label": tfrec.FixedLenFeature([6], tfrec.int64,  6)},
             path = ['/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/tfrecords/6_basic_emo_test.tfrecords'],
             index_path = ['/content/drive/MyDrive/facial_emotion_recognition_using_K-drama_dataset-main/tfrecords/6_basic_emo_test.idx'],
             random_shuffle=False,
             seed = set_seed)
        self.iter = 0
    def define_graph(self):
        inputs = self.input
        images = fn.decoders.image(inputs["image_raw"], device = "mixed", output_type = types.RGB) / 255.
        labels = inputs["label"].gpu()
        return (images, labels)
    def iter_setup(self):
        pass
# Out:
# time: 1.79 ms (started: 2022-11-20 16:37:26 +00:00)

# %% [markdown]
# ### Check test data accuracy.

# %%
# https://docs.nvidia.com/deeplearning/dali/user-guide/docs/plugins/tensorflow_plugin_api.html

if __name__ == "__main__":
    batch_size = 1
    shapes = ((batch_size, 64, 64, 3),
              (batch_size, 6))
    pipe_test = TFRecordPipelineTest(batch_size=batch_size, 
                            num_threads=4, 
                            device='gpu', 
                            device_id=0)

    with tf.device('/gpu:0'):
        ds_test = dali_tf.DALIDataset(
            pipeline=pipe_test,
            batch_size=batch_size,
            output_shapes=shapes,
            output_dtypes=(tf.float32, tf.int64),
            device_id=0)
        loss, acc = clf.evaluate(ds_test, steps=TEST_DATA_SIZE)
        print("Test accuracy:", acc)
        predictions = clf.predict(ds_test.take(5))
        print("A test output from the last layer:", predictions[0])
        print("Index of the maximum value:", np.argmax(predictions[0]))
        print("Label:", LABELS[np.argmax(predictions[0])])
# Out:
# 1282/1282 [==============================] - 6s 4ms/step - loss: 1.4399 - accuracy: 0.6232
# Test accuracy: 0.6232449412345886
# 5/5 [==============================] - 0s 3ms/step
# A test output from the last layer: [0.19838305 0.1495179  0.18533593 0.1535673  0.13978383 0.17341204]
# Index of the maximum value: 0
# Label: angry
# time: 6.7 s (started: 2022-11-20 16:37:26 +00:00)

# %%
predictions
# Out:
# array([[0.19838305, 0.1495179 , 0.18533593, 0.1535673 , 0.13978383,
#         0.17341204],
#        [0.17519467, 0.1901937 , 0.2029711 , 0.15184227, 0.11815662,
#         0.16164167],
#        [0.19838305, 0.1495179 , 0.18533593, 0.1535673 , 0.13978383,
#         0.17341204],
#        [0.30501488, 0.07296821, 0.11827336, 0.08981328, 0.22731894,
#         0.18661132],
#        [0.19838305, 0.1495179 , 0.18533593, 0.1535673 , 0.13978383,
#         0.17341204]], dtype=float32)
# time: 5.96 ms (started: 2022-11-20 16:37:33 +00:00)

# %%
# Display the tested image.

import matplotlib.pyplot as plt

data, = ds_test.take(1)
plt.imshow(data[0][0])
# Out:
# time: 172 ms (started: 2022-11-20 16:37:33 +00:00)

# %%
# Check the test data's true label.
data[1]
# Out:
# <tf.Tensor: shape=(1, 6), dtype=int64, numpy=array([[1, 0, 0, 0, 0, 0]])>
# time: 5.98 ms (started: 2022-11-20 16:37:33 +00:00)

# %%
data
# Out:
# (<tf.Tensor: shape=(1, 64, 64, 3), dtype=float32, numpy=
#  array([[[[0.03921569, 0.03529412, 0.01176471],
#           [0.05098039, 0.04705882, 0.02352941],
#           [0.04705882, 0.05098039, 0.02352941],
#           ...,
#           [0.14509805, 0.08627451, 0.05882353],
#           [0.08235294, 0.0627451 , 0.03137255],
#           [0.09411765, 0.07450981, 0.04313726]],
#
#          [[0.03921569, 0.03529412, 0.01176471],
#           [0.04313726, 0.03921569, 0.01568628],
#           [0.03529412, 0.03921569, 0.01176471],
#           ...,
#           [0.17254902, 0.11372549, 0.08627451],
#           [0.08627451, 0.06666667, 0.03529412],
#           [0.09411765, 0.07450981, 0.04313726]],
#
#          [[0.04313726, 0.04313726, 0.02745098],
#           [0.04313726, 0.04313726, 0.02745098],
#           [0.03137255, 0.04313726, 0.02352941],
#           ...,
#           [0.21568628, 0.12941177, 0.09411765],
#           [0.11372549, 0.06666667, 0.03529412],
#           [0.15294118, 0.10588235, 0.07450981]],
#
#          ...,
#
#          [[0.38431373, 0.36862746, 0.3764706 ],
#           [0.33333334, 0.31764707, 0.3254902 ],
#           [0.27058825, 0.2627451 , 0.26666668],
#           ...,
#           [0.4509804 , 0.36078432, 0.28235295],
#           [0.42352942, 0.3372549 , 0.23921569],
#           [0.39607844, 0.30980393, 0.21176471]],
#
#          [[0.30980393, 0.30588236, 0.3137255 ],
#           [0.27058825, 0.26666668, 0.27450982],
#           [0.23137255, 0.23529412, 0.25882354],
#           ...,
#           [0.43137255, 0.37254903, 0.3372549 ],
#           [0.38039216, 0.3764706 , 0.3529412 ],
#           [0.43529412, 0.43137255, 0.40784314]],
#
#          [[0.27450982, 0.27058825, 0.2784314 ],
#           [0.22745098, 0.22352941, 0.23137255],
#           [0.21568628, 0.21960784, 0.24313726],
#           ...,
#           [0.34901962, 0.2901961 , 0.25490198],
#           [0.29803923, 0.29411766, 0.27058825],
#           [0.2627451 , 0.25882354, 0.23529412]]]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 6), dtype=int64, numpy=array([[1, 0, 0, 0, 0, 0]])>)
# time: 6.28 ms (started: 2022-11-20 16:37:33 +00:00)

# %%
pred_test = clf.predict(ds_test.take(TEST_DATA_SIZE))
# Out:
# 1282/1282 [==============================] - 4s 3ms/step
# time: 5.01 s (started: 2022-11-20 16:37:33 +00:00)

# %%
true_test = np.concatenate([y for x, y in ds_test.take(TEST_DATA_SIZE)], axis=0)
# Out:
# time: 1.02 s (started: 2022-11-20 16:37:38 +00:00)

# %%
true_test.shape
# Out:
# (1282, 6)
# time: 3.5 ms (started: 2022-11-20 16:37:39 +00:00)

# %%
from sklearn.metrics import confusion_matrix

pred_test_ls = []
true_test_ls = []
for (pred, true) in zip(pred_test, true_test):
    pred_test_ls.append(np.argmax(pred))
    true_test_ls.append(np.argmax(true))

cf_matrix_test = confusion_matrix(true_test_ls, pred_test_ls)
cf_matrix_test
# Out:
# array([[672,  16,  51,   6,   8,   6],
#        [  4,   7,   1,   0,   0,   0],
#        [159,   9, 104,   0,   0,   0],
#        [  8,  19,   0,   1,   0,   0],
#        [  7,   0,   0,   0,  11,   0],
#        [129,   3,  12,   1,  44,   4]])
# time: 79.5 ms (started: 2022-11-20 16:37:39 +00:00)

# %%
import seaborn as sns

sns.heatmap(cf_matrix_test, annot=True, cmap='Blues', xticklabels=LABELS, yticklabels=LABELS, fmt='g')
plt.title('Autoencoder: 6 Class FER')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(33.0, 0.5, 'True')
# time: 706 ms (started: 2022-11-20 16:37:39 +00:00)

# %% [markdown]
# ### Check train data accuracy.

# %%
# https://docs.nvidia.com/deeplearning/dali/user-guide/docs/plugins/tensorflow_plugin_api.html

if __name__ == "__main__":
    batch_size = 1
    shapes = ((batch_size, 64, 64, 3),
              (batch_size, 6))
    pipe_train = TFRecordPipelineTrain(batch_size=batch_size, 
                            num_threads=4, 
                            device='gpu', 
                            device_id=0)

    with tf.device('/gpu:0'):
    #with strategy.scope():        
        # Create dataset
        ds_train = dali_tf.DALIDataset(
            pipeline=pipe_train,
            batch_size=batch_size,
            output_shapes=shapes,
            output_dtypes=(tf.float32, tf.int64),
            device_id=0)
        loss, acc = clf.evaluate(ds_train, steps=TRAIN_DATA_SIZE)
        print("Train accuracy:", acc)
        #predictions = clf.predict(ds_train.take(1))
        #print("A test output from the last layer:", predictions[0])
        #print("Index of the maximum value:", np.argmax(predictions[0]))
        #print("Label:", LABELS[np.argmax(predictions[0])])
# Out:
# 10249/10249 [==============================] - 43s 4ms/step - loss: 1.4272 - accuracy: 0.6217
# Train accuracy: 0.6217191815376282
# time: 42.8 s (started: 2022-11-20 16:37:40 +00:00)

# %%
pred_train = clf.predict(ds_train.take(TRAIN_DATA_SIZE))
# Out:
# 10249/10249 [==============================] - 26s 3ms/step
# time: 28.3 s (started: 2022-11-20 16:38:23 +00:00)

# %%
true_train = np.concatenate([y for x, y in ds_train.take(TRAIN_DATA_SIZE)], axis=0)
# Out:
# time: 5.41 s (started: 2022-11-20 16:38:51 +00:00)

# %%
true_train.shape
# Out:
# (10249, 6)
# time: 5.56 ms (started: 2022-11-20 16:38:56 +00:00)

# %%
pred_train_ls = []
true_train_ls = []
for (pred, true) in zip(pred_train, true_train):
    pred_train_ls.append(np.argmax(pred))
    true_train_ls.append(np.argmax(true))

cf_matrix_train = confusion_matrix(true_train_ls, pred_train_ls)
cf_matrix_train
# Out:
# array([[5374,  128,  381,   58,   74,   53],
#        [  28,   64,    1,    0,    0,    0],
#        [1264,   40,  851,   13,    3,    0],
#        [  55,  166,    0,    3,    0,    0],
#        [  97,    0,    1,    0,   51,    0],
#        [1057,   25,   89,    7,  337,   29]])
# time: 40.6 ms (started: 2022-11-20 16:38:56 +00:00)

# %%
sns.heatmap(cf_matrix_train, annot=True, cmap='Blues', xticklabels=LABELS, yticklabels=LABELS, fmt='g')
plt.title('Autoencoder: 6 Class FER (Train Data)')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(33.0, 0.5, 'True')
# time: 449 ms (started: 2022-11-20 16:38:56 +00:00)

# %%
# Out:
# time: 458 ms (started: 2022-11-20 16:38:56 +00:00)
